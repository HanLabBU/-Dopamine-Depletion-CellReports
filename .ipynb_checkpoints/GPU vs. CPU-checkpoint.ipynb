# %% [markdown]
# <h1> GPU and Parallel CPU tests </h1>
#
# Time GPU vs. CPU/frame to see if worth adupting code for GPU use:

# %%
# %matplotlib notebook 
# %load_ext autoreload
# %autoreload 2


import numpy as np
import numba
from numba import cuda, vectorize

import multiprocessing as mp

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-6222726571a1> in <module>()
#       7 import numba
#       8 from numba import cuda, vectorize
# ----> 9 from accelerate.cuda import FFTPlan, fft_inplace, ifft_inplace
#      10 import multiprocessing as mp
#      11
#
# ModuleNotFoundError: No module named 'accelerate'

# %%
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install accelerate
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# create a fake frame (just random numbers)
frame = np.random.randint(0,255,(1024,1024))
plt.imshow(frame)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %%timeit
CPU_fft = np.fft.fft2(frame)
# Out:
# 64.4 ms ± 1.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
@vectorize(['complex64(complex64, complex64)'], target='cuda')
def vmult(a, b):
    return a * b


def best_grid_size(size, tpb):
    bpg = np.ceil(np.array(size, dtype=np.float) / tpb).astype(np.int).tolist()
    return tuple(bpg)

threadperblock = 32, 8
blockpergrid = best_grid_size(tuple(reversed(frame.shape)), threadperblock)

# %%timeit
FFTPlan(shape=frame.shape, itype=np.complex64, otype=np.complex64)

# %%
# %%timeit
frame_complex = frame.astype(np.complex64)
d_frame_complex = cuda.to_device(frame_complex)
GPU_fft = fft_inplace(d_frame_complex)
