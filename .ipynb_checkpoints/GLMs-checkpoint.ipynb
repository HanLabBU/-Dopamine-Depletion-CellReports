# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('D:\\6OHDA\\')
#import mpld3
#mpld3.enable_notebook()
import numpy as np
import scipy as sci
from scipy import signal
from matplotlib import pyplot as plt
from matplotlib import gridspec
import matplotlib.colors as Mcolors
import matplotlib.cm as cmx
import sys
import h5py
from IO import *
from utils import *
from plotUtils import *
from ColorSchems import colorPallet as CP
import pptx
from pptx import Presentation 
from pptx.util import Inches
from io import BytesIO
import re
import warnings
import pandas as pd
import sqlalchemy as db
import gc
from tqdm import tqdm
import seaborn as sns
import pywt # wavelet package
import statsmodels.api as sm
import sklearn as sk

# %%
Files = ['FinalData_6OHDA.h5','FinalData_6OHDA_H.h5']
miceList = getMiceList(Files[0])

# %%
def periodCalc(day):
    if day== 0:
        return 'Healthy'
    elif day<13:
        return 'Acute' #day 1-13
    else:
        return 'Chronic' #day 14-35

# %%
def packData(data,names):
    # takes numpy array and turn to data frame for GLM training
    # Input: 
    #    data - numpy array, each column in a variable
    #    names - list of strings with column names 
    # Output:
    #    df - pandas df that has an intercept column (all 1), 
    #         and a column for each of the variables in data
    
    row,col = data.shape
    if len(names)!= col:
        if len(names) == row:
            warnings.warn("length of names don't match number of columns, data transposed")
            data = data.T
            row,col = data.shape
        else:
            raise ValueError("length of names do not match data. len names = ",len(names),", data.shape =",data.shape)
    
    df = pd.DataFrame(data=data, columns=names)
    df["Intercept"] = np.ones(row)
    return df

# %%
# %matplotlib inline
from statsmodels.genmod.families import Poisson, Gamma, Gaussian

def trainModelSm(predictors,y,k=1,plot=True,family=Gamma(link=sm.families.links.log)):
    if k<1:
        k = 1
    # no cross validation, use all data as train and return train AIC
    if k == 1: 
        model = sm.GLM(y, predictors, family=family)
        model_results = model.fit()
        b = model_results.params
#         print(model_results.summary())
        aic = model_results.aic
        y_hut = np.exp(np.sum(b*predictors,axis=1)) 
        # plot if required
        if plot: 
            fig, (ax,ax2) = plt.subplots(2,1,figsize=(10,6))
            ax.plot(y,label='y',color='k')
            ax.plot(y_hut,label='y^',color='g')
            ax2.scatter(y,y_hut,alpha=0.5)
            ax2.set_xlabel('y')
            ax2.set_ylabel('y^')
            ax.set_title("aic = {0:8.2f}".format(aic))
            ax.legend()
        return aic,model_results,b
    # cross validation,return all models
    else:
        batchSize = np.floor(len(predictors)/k)
        aic = []
        results = {}
        if plot:
            fig, ax = plt.subplots(k,1,figsize=(10,6))
        for itr in range(k):
            # divide data into train and test
            testInds = predictors.index.isin(np.arange(itr*batchSize,(itr+1)*batchSize))
            trainData = predictors[~testInds]
            trainY = y[~testInds]
            testData = predictors[testInds]
            testY = y[testInds]
            # train the model
            model = sm.GLM(trainY, trainData, family=family)
            model_results = model.fit()
            b = model_results.params
            aic.append(model_results.aic)
            results[str(itr)] = model_results
            y_hut = np.exp(np.sum(b*testData,axis=1))
            if plot:
                ax[itr].plot(np.arange(0,np.max(testY.shape)),testY,label='y',color='k')
                ax[itr].plot(np.arange(0,np.max(testY.shape)),y_hut,label='y^',color='g')
                ax[itr].set_title("train aic = {0:8.2f}".format(model_results.aic))
        bestFit = np.argmax(aic)
        if plot:
            sns.displot(aic,kde=True)
        print(results[str(bestFit)].summary())
        return aic,results,1
# Out:
# <ipython-input-5-e9e9fea6124b>:4: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   def trainModelSm(predictors,y,k=1,plot=True,family=Gamma(link=sm.families.links.log)):

# %%
from statsmodels import graphics
def compareNested(model1,model2):
    dev1 = model1.deviance 
    dev2 = model2.deviance 
    p = 1 - sci.stats.chi2.cdf(dev1 - dev2, len(model1.params)-len(model2.params)) 
    print('p:', p)
    return p
def residualPlot(model,predictors,fs=20,res = 'Person'):
    fig, (ax,ax2) = plt.subplots(2,1)
    resType = {'Person':model.resid_pearson,
               'Raw':model.resid_response}
    R = np.cumsum(resType[res])
    t = np.arange(len(R))/fs
    ax.plot(t,R)
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('Cumulative Residuals')
    b = model.params
    y_hut = np.exp(np.sum(b*predictors,axis=1)) 
    ax2.scatter(y_hut, resType[res],alpha=0.3)
    ax2.hlines(0, 0, np.Inf)
    ax2.set_title('Residual Dependence Plot')
    ax2.set_ylabel(res+' Residuals')
    ax2.set_xlabel('y^')
    
    resid = model.resid_deviance.copy()
    graphics.gofplots.qqplot(resid, line='r')

# %%
# data = getData(Files[1],['trace','speed','rot'],period ='Pre', mice='1208', day = lambda x: x==0)
dff = np.sum(data['1208_BaselineL']['trace']['dff'],axis=0,keepdims=True)
# dff = dff[:,:-1]
speed = data['1208_BaselineL']['speed']['speed']
rot = data['1208_BaselineL']['rot']['rot']
acc = acc = speed[:,1:]-speed[:,:-1]
acc = np.append(acc.T,np.asarray([0]).reshape(1,1),0).T
acc2 = acc**2


df = packData(np.concatenate((speed,rot,acc,acc2)),["speed","rot","acc","acc^2"])
# Out:
# <ipython-input-23-bcaa56cb2ae5>:13: UserWarning: length of names don't match number of columns, data transposed
#   warnings.warn("length of names don't match number of columns, data transposed")

# %%
aic,model_results,b =trainModelSm(df,dff[0,:],k=3)
# print(dff[0,:].shape,len(df))
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                 7934
# Model:                            GLM   Df Residuals:                     7929
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                         0.11880
# Method:                          IRLS   Log-Likelihood:                -14649.
# Date:                Thu, 15 Apr 2021   Deviance:                       826.77
# Time:                        14:56:35   Pearson chi2:                     942.
# No. Iterations:                    16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# speed          0.0343      0.001     36.010      0.000       0.032       0.036
# ...

# %%
# dff = np.sum(data['1208_BaselineA']['trace']['dff'],axis=0,keepdims=True)
# dff = dff[:,:-1]
# speed = data['1208_BaselineA']['speed']['speed']
# rot = data['1208_BaselineA']['rot']['rot']
# acc = acc = speed[:,1:]-speed[:,:-1]
# acc = np.append(acc.T,np.asarray([0]).reshape(1,1),0).T
# acc2 = acc**2


# df = packData(np.concatenate((speed,rot,acc,acc2)),["speed","rot","acc","acc^2"])
aic,model_results,b =trainModelSm(df,dff[0,:],k=5)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                 9520
# Model:                            GLM   Df Residuals:                     9515
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                        0.044783
# Method:                          IRLS   Log-Likelihood:                -30341.
# Date:                Thu, 15 Apr 2021   Deviance:                       386.11
# Time:                        21:12:05   Pearson chi2:                     426.
# No. Iterations:                    14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# speed          0.0147      0.000     31.845      0.000       0.014       0.016
# ...

# %%
dff = np.sum(data['1208_BaselineL']['trace']['dff'],axis=0,keepdims=True)
# dff = dff[:,:-1]
speed = data['1208_BaselineL']['speed']['speed']
rot = data['1208_BaselineL']['rot']['rot']
acc = acc = speed[:,1:]-speed[:,:-1]
acc = np.append(acc.T,np.asarray([0]).reshape(1,1),0).T
acc2 = acc**2


df = packData(np.concatenate((speed,rot,acc,acc2)),["speed","rot","acc","acc^2"])

aic1,model_results1,b1 =trainModelSm(df,dff[0,:],k=1)
# print(df.columns)
df2 = df.drop('rot', axis=1)
aic2,model_results2,b2 =trainModelSm(df2,dff[0,:],k=1)
compareNested(model_results1,model_results2)
# Out:
# <ipython-input-23-bcaa56cb2ae5>:13: UserWarning: length of names don't match number of columns, data transposed
#   warnings.warn("length of names don't match number of columns, data transposed")
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                11900
# Model:                            GLM   Df Residuals:                    11895
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                         0.11755
# Method:                          IRLS   Log-Likelihood:                -21557.
# Date:                Thu, 15 Apr 2021   Deviance:                       1235.5
# Time:                        22:08:18   Pearson chi2:                 1.40e+03
# No. Iterations:                    15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
residualPlot(model_results1,df)
residualPlot(model_results2,df2)

# %%
dff2 = data['1208_BaselineL']['trace']['dff']
dff2 = dff2[1,:]+1

a = plt.hist(dff2,bins=100)
plt.title('dff distribution')
# Out:
# Text(0.5, 1.0, 'dff distribution')

# %%
dff2 = data['1208_BaselineL']['trace']['dff']
dff2 = dff2[1,:]+1
dff2 = smooth(dff2,20)
aic1,model_results1,b1 =trainModelSm(df,dff2,k=1)
# print(df.columns)
df2 = df.drop('acc^2', axis=1)
aic2,model_results2,b2 =trainModelSm(df2,dff2,k=1)
compareNested(model_results1,model_results2)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                11900
# Model:                            GLM   Df Residuals:                    11895
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                       0.0011666
# Method:                          IRLS   Log-Likelihood:                 23147.
# Date:                Tue, 20 Apr 2021   Deviance:                       13.596
# Time:                        12:51:31   Pearson chi2:                     13.9
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# speed          0.0028   7.55e-05     36.613      0.000       0.003       0.003
# ...

# %%
residualPlot(model_results1,df)
residualPlot(model_results2,df2)

# %%
# df3 = df.copy()
# df3['onset'] = 0
# df3['onset'].iloc[np.random.random_integers(0,len(df),20)] = 1
df3['onset'].unique()
plt.plot(dff2[:4000])

# %%
aic1,model_results1,b1 =trainModelSm(df,dff2,k=1,family=Gaussian())
residualPlot(model_results1,df)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                11900
# Model:                            GLM   Df Residuals:                    11895
# Model Family:                Gaussian   Df Model:                            4
# Link Function:               identity   Scale:                       0.0018113
# Method:                          IRLS   Log-Likelihood:                 20684.
# Date:                Tue, 20 Apr 2021   Deviance:                       21.545
# Time:                        12:50:43   Pearson chi2:                     21.5
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# speed          0.0028    9.4e-05     30.249      0.000       0.003       0.003
# ...

# %%
del dff,speed,period

# %%
# try fitting for all data
data = getData(Files[1],['trace','speed'],period ='Pre', mice='1208')
for ind,sess in enumerate(data.keys()):
    if sess[5] == 'B':
            day = 0
    else:
        day = int(re.findall(r'\d+',sess[5:])[0])
    if ind==0:
        dff = np.mean(data[sess]['trace']['dff'],axis=0,keepdims=True)
        speed = data[sess]['speed']['speed']
        if len(dff.T)>len(speed.T):
            dff = dff[0,:len(speed.T)]
        period = np.zeros(dff.shape)
        if (day >0)&(day<13):
            period = period+1
        elif day>=13:
            period = period+2
    else:
        dfft = np.mean(data[sess]['trace']['dff'],axis=0,keepdims=True)
        speedt = data[sess]['speed']['speed']
        if np.max(dfft.shape)>np.max(speedt.shape):
            dfft = dfft[0,:len(speedt.T)]
            print(len(dfft.T),len(speedt.T))
        dff = np.append(dff,dfft)
        speed = np.append(speed,speedt)
        p = np.zeros(dfft.shape)
        del dfft, speedt
        if (day >0)&(day<13):
            p = p+1
        elif day>=13:
            p = p+2
        period = np.append(period,p)


df = packData(np.concatenate((np.expand_dims(dff,1),np.expand_dims(period,1)),axis=1),["dff","period"])
# Out:
# d:\6OHDA\IO.py:282: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   dff = hf[m][s]['traces']['dff'].value
# d:\6OHDA\IO.py:152: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   speed = hf[m][s]['mvmt']['speed'].value
# cleaning up trace data
# cleaning up speed data
# 11899 11899
# 11899 11899
# 11899 11899
# 11899 11899
# 11898 11898
# 11899 11899
# 11899 11899

# %%
aic1,model_results1,b1 =trainModelSm(df,speed,k=1)
# print(len(df),speed.shape)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166588
# Model Family:                   Gamma   Df Model:                            2
# Link Function:                    log   Scale:                          3.5694
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Wed, 28 Apr 2021   Deviance:                   1.5140e+06
# Time:                        14:51:46   Pearson chi2:                 5.95e+05
# No. Iterations:                    20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dff            0.2924      0.066      4.430      0.000       0.163       0.422
# ...

# %%
# %matplotlib notebook
plt.plot(speed)
plt.plot(dff)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# try fitting for all data
data = getData(Files[1],['trace','speed'],period ='Pre', mice='1208')
for ind,sess in enumerate(data.keys()):
    if sess[5] == 'B':
            day = 0
    else:
        day = int(re.findall(r'\d+',sess[5:])[0])
    if ind==0:
        dff = np.sum(data[sess]['trace']['dff'],axis=0,keepdims=True)
        dff = (dff-np.min(dff))/(np.max(dff)-np.min(dff))
        speed = data[sess]['speed']['speed']
        speed = (speed - np.min(speed))/(np.max(speed)-np.min(speed))
        if len(dff.T)>len(speed.T):
            dff = dff[0,:len(speed.T)]
        period = np.zeros(dff.shape)
        if (day >0)&(day<13):
            period = period+1
        elif day>=13:
            period = period+2
    else:
        dfft = np.sum(data[sess]['trace']['dff'],axis=0,keepdims=True)
        dfft = (dfft-np.min(dfft))/(np.max(dfft)-np.min(dfft))
        speedt = data[sess]['speed']['speed']
        speedt = (speedt - np.min(speedt))/(np.max(speedt)-np.min(speedt))
        if np.max(dfft.shape)>np.max(speedt.shape):
            dfft = dfft[0,:len(speedt.T)]
            print(len(dfft.T),len(speedt.T))
        dff = np.append(dff,dfft)
        speed = np.append(speed,speedt)
        p = np.zeros(dfft.shape)
        del dfft, speedt
        if (day >0)&(day<13):
            p = p+1
        elif day>=13:
            p = p+2
        period = np.append(period,p)


df = packData(np.concatenate((np.expand_dims(dff,1),np.expand_dims(period,1)),axis=1),["dff","period"])
# Out:
# d:\6OHDA\IO.py:282: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   dff = hf[m][s]['traces']['dff'].value
# d:\6OHDA\IO.py:152: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   speed = hf[m][s]['mvmt']['speed'].value
# cleaning up trace data
# cleaning up speed data
# 11899 11899
# 11899 11899
# 11899 11899
# 11899 11899
# 11898 11898
# 11899 11899
# 11899 11899

# %%
aic1,model_results1,b1 =trainModelSm(df,speed,k=1)
# Out:
# C:\Users\dzemel\Miniconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166588
# Model Family:                   Gamma   Df Model:                            2
# Link Function:                    log   Scale:                          3.8630
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Wed, 28 Apr 2021   Deviance:                   1.4869e+06
# Time:                        15:03:06   Pearson chi2:                 6.44e+05
# No. Iterations:                    25
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# %matplotlib notebook
plt.plot(speed)
plt.plot(dff,alpha = 0.6)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
aic1,model_results1,b1 =trainModelSm(df,speed,k=1,family=Gaussian())
residualPlot(model_results1,df)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166588
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                        0.015658
# Method:                          IRLS   Log-Likelihood:             1.0986e+05
# Date:                Wed, 28 Apr 2021   Deviance:                       2608.4
# Time:                        15:10:21   Pearson chi2:                 2.61e+03
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dff            0.1813      0.002     96.216      0.000       0.178       0.185
# ...

# %%
aic1,model_results1,b1 =trainModelSm(df,speed,k=1)
residualPlot(model_results1,df)
# Out:
# C:\Users\dzemel\Miniconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166588
# Model Family:                   Gamma   Df Model:                            2
# Link Function:                    log   Scale:                          3.8630
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Wed, 28 Apr 2021   Deviance:                   1.4869e+06
# Time:                        15:11:46   Pearson chi2:                 6.44e+05
# No. Iterations:                    25
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
# try fitting for all data
data = getData(Files[1],['trace','speed'],period ='Pre', mice='1208')
for ind,sess in enumerate(data.keys()):
    if sess[5] == 'B':
            day = 0
    else:
        day = int(re.findall(r'\d+',sess[5:])[0])
    if ind==0:
        dff = np.sum(data[sess]['trace']['dff'],axis=0,keepdims=True)
        dff = (dff-np.min(dff))/(np.max(dff)-np.min(dff))
        dff = smooth(dff,20)+1
        speed = data[sess]['speed']['speed']
        speed = (speed - np.min(speed))/(np.max(speed)-np.min(speed))
        if len(dff.T)>len(speed.T):
            dff = dff[:len(speed.T)]
        period = np.zeros(dff.shape)
        if (day >0)&(day<13):
            period = period+1
        elif day>=13:
            period = period+2
    else:
        dfft = np.sum(data[sess]['trace']['dff'],axis=0,keepdims=True)
        dfft = (dfft-np.min(dfft))/(np.max(dfft)-np.min(dfft))
        dfft = smooth(dfft,20)+1
        speedt = data[sess]['speed']['speed']
        speedt = (speedt - np.min(speedt))/(np.max(speedt)-np.min(speedt))
        if np.max(dfft.shape)>np.max(speedt.shape):
            dfft = dfft[:len(speedt.T)]
            print(len(dfft.T),len(speedt.T))
        dff = np.append(dff,dfft)
        speed = np.append(speed,speedt)
        p = np.zeros(dfft.shape)
        del dfft, speedt
        if (day >0)&(day<13):
            p = p+1
        elif day>=13:
            p = p+2
        period = np.append(period,p)


df = packData(np.concatenate((np.expand_dims(dff,1),np.expand_dims(period,1)),axis=1),["dff","period"])
# Out:
# d:\6OHDA\IO.py:282: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   dff = hf[m][s]['traces']['dff'].value
# d:\6OHDA\IO.py:152: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   speed = hf[m][s]['mvmt']['speed'].value
# cleaning up trace data
# cleaning up speed data
# 11899 11899
# 11899 11899
# 11899 11899
# 11899 11899
# 11898 11898
# 11899 11899
# 11899 11899

# %%
aic1,model_results1,b1 =trainModelSm(df,speed,k=1)
residualPlot(model_results1,df)
# Out:
# C:\Users\dzemel\Miniconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166588
# Model Family:                   Gamma   Df Model:                            2
# Link Function:                    log   Scale:                          3.8463
# Method:                          IRLS   Log-Likelihood:                    inf
# Date:                Wed, 28 Apr 2021   Deviance:                   1.4846e+06
# Time:                        15:21:36   Pearson chi2:                 6.41e+05
# No. Iterations:                    25
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
a = plt.hist(dff,1000)

# %%
a = plt.hist(df['speed'],100)

# %%
data = getData(Files[1],['trace','speed','rot'],period ='Pre', mice='1208')
dff3 = np.nansum(data['1208_day12']['trace']['dff'],axis=0,keepdims=True)
dff3 = dff3 +20
# dff = dff[:,:-1]
speed = data['1208_day12']['speed']['speed']
rot = data['1208_day12']['rot']['rot']
acc = acc = speed[:,1:]-speed[:,:-1]
acc = np.append(acc.T,np.asarray([0]).reshape(1,1),0).T
acc2 = acc**2


df2 = packData(np.concatenate((speed,rot,acc,acc2)),["speed","rot","acc","acc^2"])
aic,model_results,b =trainModelSm(df2,dff3[0,:],k=1)
residualPlot(model_results,df2)
# Out:
# d:\6OHDA\IO.py:282: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   dff = hf[m][s]['traces']['dff'].value
# d:\6OHDA\IO.py:152: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   speed = hf[m][s]['mvmt']['speed'].value
# d:\6OHDA\IO.py:245: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   rot = hf[m][s]['mvmt']['rotation'].value
# cleaning up trace data
# cleaning up speed data
# cleaning up rot data
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                11900
# Model:                            GLM   Df Residuals:                    11895
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                        0.047321
# Method:                          IRLS   Log-Likelihood:                -33295.
# ...

# %%
df = packData(np.concatenate((np.expand_dims(dff,1),np.expand_dims(period,1),np.expand_dims(speed,1),),axis=1),["dff","period","speed"])

# %%
# import statsmodels.formula.api as smf
def fitglmFormula(formula,predictors,y,k=1,plot=True,family=Gamma(link=sm.families.links.log)):
    model = smf.glm(formula=formula, data=df, family=family)
    model_results = model.fit()
    b = model_results.params
    print(model_results.summary())
    aic = model_results.aic
    y_hut = model.predict(b)
    # # plot if required
    # if plot: 
    fig, (ax,ax2) = plt.subplots(2,1,figsize=(10,6))
    ax.plot(y,label='y',color='k')
    ax.plot(y_hut,label='y^',color='g')
    ax2.scatter(y,y_hut,alpha=0.5)
    ax2.set_xlabel('y')
    ax2.set_ylabel('y^')
    ax.set_title("aic = {0:8.2f}".format(aic))
    ax.legend()
    return model,model_results
# Out:
# <ipython-input-169-24cbdceafb65>:2: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   def fitglmFormula(formula,predictors,y,k=1,plot=True,family=Gamma(link=sm.families.links.log)):

# %%
model1, model_results1 = fitglmFormula("speed ~ 1",df,df['speed'])
model2, model_results2 = fitglmFormula("speed ~ 1+dff",df,df['speed'])
model3, model_results3 = fitglmFormula("speed ~ 1+dff+dff*period",df,df['speed'])
# Out:
# <ipython-input-147-071a9da1be87>:3: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   model = smf.glm(formula=formula, data=df, family=Gamma(link=sm.families.links.log))
# C:\Users\dzemel\Miniconda3\lib\site-packages\statsmodels\genmod\families\family.py:735: RuntimeWarning: divide by zero encountered in log
#   ll_obs -= special.gammaln(weight_scale) + np.log(endog)
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  speed   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166590
# Model Family:                   Gamma   Df Model:                            0
# Link Function:                    log   Scale:                          3.5330
# Method:                          IRLS   Log-Likelihood:                    inf
# ...

# %%
def residualPlotFormula(model,model_results,fs=20,res = 'Person'):
    fig, (ax,ax2) = plt.subplots(2,1)
    resType = {'Person':model_results.resid_pearson,
               'Raw':model_results.resid_response}
    R = np.cumsum(resType[res])
    t = np.arange(len(R))/fs
    ax.plot(t,R)
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('Cumulative Residuals')
    b = model_results.params
    y_hut = model.predict(b)
    ax2.scatter(y_hut, resType[res],alpha=0.3)
    ax2.hlines(0, 0, np.Inf)
    ax2.set_title('Residual Dependence Plot')
    ax2.set_ylabel(res+' Residuals')
    ax2.set_xlabel('y^')
    
    resid = model_results.resid_deviance.copy()
    graphics.gofplots.qqplot(resid, line='r')

# %%
residualPlotFormula(model2,model_results2)
residualPlotFormula(model3,model_results3)

# %%
# try fitting for all data
data = getData(Files[1],['trace','speed'],period ='Pre', mice='1208')
m = '1208'
for ind,sess in enumerate(data.keys()):
    if sess[5] == 'B':
            day = 0
    else:
        day = int(re.findall(r'\d+',sess[5:])[0])
    if ind==0:
        dff = np.sum(getOnsetOrPeriod(m,sess,'Pre','caOnset_Hf'),axis=0,keepdims=True)
#         dff = (dff-np.min(dff))/(np.max(dff)-np.min(dff))
        speed = data[sess]['speed']['speed']
        speed = (speed - np.min(speed))/(np.max(speed)-np.min(speed))
        if len(dff.T)>len(speed.T):
            dff = dff[0,:len(speed.T)]
        period = np.zeros(dff.shape)
        if (day >0)&(day<13):
            period = period+1
        elif day>=13:
            period = period+2
    else:
        dfft = np.sum(getOnsetOrPeriod(m,sess,'Pre','caOnset_Hf'),axis=0,keepdims=True)
#         dfft = (dfft-np.min(dfft))/(np.max(dfft)-np.min(dfft))
#         dfft = smooth(dfft,20)+1
        speedt = data[sess]['speed']['speed']
        speedt = (speedt - np.min(speedt))/(np.max(speedt)-np.min(speedt))
        if np.max(dfft.shape)>np.max(speedt.shape):
            dfft = dfft[0,:len(speedt.T)]
            print(len(dfft.T),len(speedt.T))
        dff = np.append(dff,dfft)
        speed = np.append(speed,speedt)
        p = np.zeros(dfft.shape)
        del dfft, speedt
        if (day >0)&(day<13):
            p = p+1
        elif day>=13:
            p = p+2
        period = np.append(period,p)


df = packData(np.concatenate((np.expand_dims(dff,1),np.expand_dims(period,1),np.expand_dims(speed,1),),axis=1),["dff","period","speed"])
# Out:
# cleaning up trace data
# cleaning up speed data
# 11899 11899
# 11899 11899
# 11899 11899
# 11899 11899
# 11898 11898
# 11899 11899
# 11899 11899

# %%
a = plt.hist(dff,100)

# %%
model1, model_results1 = fitglmFormula("speed ~ 1",df,df['speed'],family = Poisson())
model2, model_results2 = fitglmFormula("speed ~ 1+dff",df,df['speed'],family = Poisson())
model3, model_results3 = fitglmFormula("speed ~ 1+dff+dff*period",df,df['speed'],family = Poisson())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  speed   No. Observations:               166591
# Model:                            GLM   Df Residuals:                   166590
# Model Family:                 Poisson   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -37837.
# Date:                Thu, 29 Apr 2021   Deviance:                       26035.
# Time:                        19:06:37   Pearson chi2:                 4.03e+04
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.6812      0.009   -286.377      0.000      -2.700      -2.663
# ...

# %%
residualPlotFormula(model2,model_results2)
residualPlotFormula(model3,model_results3)

# %%
compareNested(model_results2,model_results3)
# Out:
# p: nan
# nan

# %%
dev2 = model_results3.deviance
dev1 = model_results2.deviance
p = 1 - sci.stats.chi2.cdf(dev1 - dev2, 500) 
print(p)
# Out:
# 5.014416698667645e-05

# %% [markdown]
# <h2> method #1: directly model neuron -> speed and compare residuals </h2>

# %%
# use random 100 neurons for each session. 
# train on first half of trace, test on secound half
# save resedials of both. 
m = '1208'
data = getData(Files[1],['trace','speed'],period ='Pre', mice=m)
testRes = {'Healthy':{'bins':[],'weights':[]},'Acute':{'bins':[],'weights':[]},'Chronic':{'bins':[],'weights':[]}}
trainRes = {'Healthy':{'bins':[],'weights':[]},'Acute':{'bins':[],'weights':[]},'Chronic':{'bins':[],'weights':[]}}
binwidth = 1
for sess in tqdm(data.keys()):
    if sess[5] == 'B':
        day = 0
    else:
        day = int(re.findall(r'\d+',sess[5:])[0])
    period = periodCalc(day)
    speed = data[sess]['speed']['speed']
    nNeurons = data[sess]['trace']['dff'].shape[0]
    print(sess)
    for itr in range(100):
        modelNeurons = np.random.permutation(nNeurons)
        modelNeurons = modelNeurons[0:100]
        dff = data[sess]['trace']['dff'][modelNeurons,:]
        dff = dff +2
    
        if np.max(dff.shape)>np.max(speed.shape):
                dff = dff[:,:len(speed.T)]
   
        df2 = packData(dff[:,:6000],list(map(str, modelNeurons))) 
        try: 
            aic,model_results,b =trainModelSm(df2,speed[0,:6000],k=1,plot=False)
        except: 
            print(sess, 'failed iteration ',itr)
            continue
        df3 = packData(dff[:,6001:],list(map(str, modelNeurons))) 
        l = model_results.predict(df3)-speed[0,6001:]
        histW,bins = np.histogram(l,bins=np.arange(np.floor(np.min(l)),np.ciel(np.max(l)),binwidth))
        bins = bins[1:]
        bins = bins[histW!=0]
        histW[histW!=0]
        for a, val in zip(bins, histW):
            if a in a1:
                testRes[period]['weights'][testRes[period]['bins'].index(a)] = testRes[period]['weights'][testRes[period]['bins'].index(a)] + val
            else:
                testRes[period]['weights'].append(val)
                testRes[period]['bins'].append(a)
        l = model_results.resid_response
        histW,bins = np.histogram(l,bins=np.arange(np.min(l),np.max(l),binwidth))
        bins = bins[1:]
        trainRes[period]['bins'].append(bins[histW!=0]) 
        trainRes[period]['weights'].append(histW[histW!=0])
# Out:
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
# cleaning up trace data
# cleaning up speed data
# 1208_BaselineA
# <ipython-input-4-bcaa56cb2ae5>:13: UserWarning: length of names don't match number of columns, data transposed
#   warnings.warn("length of names don't match number of columns, data transposed")
#   7%|█████▊                                                                            | 1/14 [02:10<28:12, 130.16s/it]
# 1208_BaselineL
#  14%|███████████▋                                                                      | 2/14 [04:09<25:21, 126.83s/it]
# 1208_BaselineS
#  14%|███████████▋                                                                      | 2/14 [07:04<42:25, 212.09s/it]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-28-0c12fac55df0> in <module>
# ...

# %%
a1 = [1,2,3,5,6,8]
a2 = [1,4,5,6,7,8,9,-1,-12]
val1 = [1,1,1,1,1,1]
vals2 = [1,1,1,1,1,1,1,1,1]

print(a1,val1)
for a, val in zip(a2, vals2):
    if a in a1:
        val1[a1.index(a)] = val1[a1.index(a)] + val
    else:
        val1.append(val)
        a1.append(a)
print(a1,val1)
# Out:
# [1, 2, 3, 5, 6, 8] [1, 1, 1, 1, 1, 1]
# [1, 2, 3, 5, 6, 8, 4, 7, 9, -1, -12] [2, 1, 1, 2, 2, 2, 1, 1, 1, 1, 1]

# %%
for idI,item in enumerate(testRes['Healthy']):
#     print(item.shape)
    sns.displot(item,label=period)
    if idI>3:
        break

# %%
# m = '1208'
# data = getData(Files[1],['trace','speed'],period ='Pre', mice=m)
# sess = '1208_BaselineA'
# if sess[5] == 'B':
#     day = 0
# else:
#     day = int(re.findall(r'\d+',sess[5:])[0])
# period = periodCalc(day)
# speed = data[sess]['speed']['speed']
# nNeurons = data[sess]['trace']['dff'].shape[0]
# for itr in range(1):
#     modelNeurons = np.random.permutation(nNeurons)
#     modelNeurons = modelNeurons[0:100]
#     dff = data[sess]['trace']['dff'][modelNeurons,:]
#     dff = dff +2

#     if np.max(dff.shape)>np.max(speed.shape):
#             dff = dff[:,:len(speed.T)]

#     df2 = packData(dff[:,:6000],list(map(str, modelNeurons))) 
#     try: 
#         aic,model_results,b =trainModelSm(df2,speed[0,:6000],k=1,plot=False)
#     except: 
#         print(sess, 'failed iteration ',itr)
#         continue
#     df3 = packData(dff[:,6001:],list(map(str, modelNeurons))) 
#     l = model_results.predict(df3)
# histW,bins = np.histogram(l,bins=np.arange(np.min(l),np.max(l),0.1))
l = model_results.predict(df3)-speed[0,6001:]
plt.hist(l,bins=np.arange(np.min(l),np.max(l),1))
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 3.000e+00, 4.000e+00, 0.000e+00, 2.000e+00, 3.000e+00,
#         3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 4.000e+00, 5.000e+00,
#         3.000e+00, 7.000e+00, 8.000e+00, 5.000e+00, 9.000e+00, 1.400e+01,
#         6.000e+00, 1.100e+01, 8.000e+00, 1.600e+01, 1.300e+01, 9.000e+00,
#         1.800e+01, 2.100e+01, 2.000e+01, 2.200e+01, 2.100e+01, 1.700e+01,
#         2.700e+01, 2.500e+01, 3.600e+01, 3.700e+01, 4.400e+01, 4.900e+01,
#         4.800e+01, 5.300e+01, 4.900e+01, 5.900e+01, 6.900e+01, 9.600e+01,
#         1.430e+02, 3.310e+02, 2.912e+03, 1.250e+03, 1.430e+02, 7.900e+01,
# ...
